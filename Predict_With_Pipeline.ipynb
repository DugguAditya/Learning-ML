# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('models/pipe.pkl', 'rb'))

# %%
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 's'], dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# /Users/aditya/Documents/ML/ML-Practice/Myenv/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /Users/aditya/Documents/ML/ML-Practice/Myenv/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
